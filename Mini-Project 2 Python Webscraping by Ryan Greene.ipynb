# %%
## Import modules and display the versions where applicable.

import requests
import pandas as pd
import sqlite3 as sq
import lxml.html
from bs4 import BeautifulSoup as soup

print(requests.__version__)
print(pd.__version__)
# Out:
# 2.18.4
# 0.23.0

# %%
## I'm going to take a look at my all of the feats in the Tabletop RPG Pathfinder.

responce = requests.get("http://www.d20pfsrd.com/feats/feat-tree")

# %%
##  Running everything through Beautifulsoup and lxml.
soup = BeautifulSoup(pageResponse.content,'lxml')

# %%
#Grabs all the tables in the code-- and the table has all of the feats. We'll make this into a dataframe.
table = soup.find_all('table')[0]
df = pd.read_html(str(table))[0]
df
# Out:
#                              0  \
# 0                         Feat
# 1         Abundant Revelations
# 2                 Accursed Hex
# 3                    Acrobatic
# 4            Additional Traits
# 5               Adept Champion
# 6         Advanced Ranger Trap
# 7             Agile Maneuvers*
# 8              Under and Over*
# 9                    Alertness
# 10           Uncanny Alertness
# 11           Alignment Channel
# 12         Amateur Gunslinger*
# 13             Animal Affinity
# 14                  Antagonize
# 15                Arcane Blast
# 16               Arcane Shield
# 17              Arcane Strike*
# 18         Dispelling Critical
# 19               Arcane Talent
# 20    Armor Proficiency, Light
# 21      Arcane Armor Training*
# 22       Arcane Armor Mastery*
# 23   Armor Proficiency, Medium
# 24       Arcane Armor Mastery*
# 25    Armor Proficiency, Heavy
# 26         Aspect of the Beast
# 27                    Athletic
# 28                        Feat
# 29               Blade Binder*
# ..                         ...
# 651             Maximize Spell
# 652             Merciful Spell
# 653           Persistent Spell
# 654             Piercing Spell
# 655              Quicken Spell
# 656                Reach Spell
# 657                 Rime Spell
# 658            Selective Spell
# 659            Sickening Spell
# 660               Silent Spell
# 661                Still Spell
# 662           Thanatopic Spell
# 663            Threnodic Spell
# 664           Thundering Spell
# 665             Toppling Spell
# 666                Widen Spell
# 667             Teamwork Feats
# 668         Allied Spellcaster
# 669           Brutal Grappler*
# 670       Coordinated Defense*
# 671     Coordinated Maneuvers*
# 672             Duck and Cover
# 673                   Ensemble
# 674                   Lookout*
# 675                  Outflank*
# 676       Paired Opportunists*
# 677            Precise Strike*
# 678               Shield Wall*
# 679            Shielded Caster
# 680               Swap Places*
#
#                                                      1  \
# 0                                        Prerequisites
# 1                                Mystery class feature
# 2                                    Hex class feature
# 3                                                    —
# 4                                                    —
# 5       Smite evil class feature, base attack bonus +5
# 6                 Trap class feature, ranger level 5th
# 7                                                    —
# 8               Agile Maneuvers, Small size or smaller
# 9                                                    —
# 10                                           Alertness
# 11                        Channel energy class feature
# 12        No levels in a class with grit class feature
# 13                                                   —
# 14                                                   —
# 15               Arcane spellcaster, caster level 10th
# 16               Arcane spellcaster, caster level 10th
# 17                       Ability to cast arcane spells
# 18   Arcane strike, base attack bonus + 11, ability...
# 19                     Cha 10; elf, half-elf, or gnome
# 20                                                   —
# 21          Armor Proficiency, Light, caster level 3rd
# 22   Arcane Armor Training, Armor Proficiency, Medi...
# 23                            Armor Proficiency, Light
# 24   Arcane Armor Training, Armor Proficiency, Medi...
# 25                           Armor Proficiency, Medium
# 26                            Wild shape class feature
# 27                                                   —
# 28                                       Prerequisites
# 29   Base attack bonus +4, proficiency with khopesh...
# ..                                                 ...
# 651                                                  —
# 652                                                  —
# 653                                                  —
# 654                                                  —
# 655                                                  —
# 656                                                  —
# 657                                                  —
# 658                                Spellcraft 10 ranks
# 659                                                  —
# 660                                                  —
# 661                                                  —
# 662  Knowledge (religion) 6 ranks, Spell Focus (nec...
# 663  Knowledge (religion) 6 ranks, Spell Focus (enc...
# 664                                                  —
# 665                                                  —
# 666                                                  —
# 667                                      Prerequisites
# 668                                   Caster level 1st
# 669                                    Half-orc or orc
# 670                                                  —
# 671                                                  —
# 672                                                  —
# 673                                    Perform 5 ranks
# 674                                                  —
# 675                               Base attack bonus +4
# 676                                                  —
# 677                       Dex 13, base attack bonus +1
# 678                                 Shield Proficiency
# 679                                                  —
# 680                                                  —
#
#                                                      2             3        4
# 0                                             Benefits  Feat Type(s)   Source
# 1          Use a single revelation more times each day             G   PRG:UM
# 2    Target a creature with a hex a second time tha...             G   PRG:UM
# 3                +2 bonus on Acrobatics and Fly checks             G  PRG:CRB
# 4                 Gain two additional character traits             G  PRG:APG
# 5    Trade smite evil damage for bonus on combat ma...             G   PRG:UC
# 6    Add +1 to the Disable Device and Perception ch...             G   PRG:UM
# 7         Use your Dex bonus when calculating your CMB          G, C  PRG:CRB
# 8    Failed grapples against you cause attacker to ...          G, C  PRG:APG
# 9       +2 bonus on Perception and Sense Motive checks             G  PRG:CRB
# 10   +1 on Perception and Sense Motive checks and a...             G   PRG:UM
# 11           Channel energy can heal or harm outsiders             G  PRG:CRB
# 12   Gain limited amount of grit and access to guns...          G, C   PRG:UC
# 13           +2 bonus on Handle Animal and Ride checks             G  PRG:CRB
# 14       Use Diplomacy or Intimidate to goad creatures             G   PRG:UM
# 15                Sacrifice a spell to make ray attack             G  PRG:APG
# 16    Sacrifice a spell to gain deflection bonus to AC             G  PRG:APG
# 17          +1 damage and weapons are considered magic          G, C  PRG:CRB
# 18       After critical hit, you may cast dispel magic       G, Crit   PRG:UC
# 19   Cast a 0-level spell 3 times per day as a spel...             G  PRG:APG
# 20   No penalties on attack rolls while wearing lig...             G  PRG:CRB
# 21      Reduce your arcane spell failure chance by 10%          G, C  PRG:CRB
# 22      Reduce your arcane spell failure chance by 20%          G, C  PRG:CRB
# 23   No penalties on attack rolls while wearing med...             G  PRG:CRB
# 24      Reduce your arcane spell failure chance by 20%          G, C  PRG:CRB
# 25   No penalties on attack rolls while wearing hea...             G  PRG:CRB
# 26                 Gain one of four bestial advantages             G  PRG:APG
# 27                   +2 bonus on Climb and Swim checks             G  PRG:CRB
# 28                                            Benefits  Feat Type(s)   Source
# 29          +2 bonus to CMB checks with blade-binding.          G, C   PCh:CS
# ..                                                 ...           ...      ...
# 651                           Maximize spell variables            MM  PRG:CRB
# 652  Spell inflicts nonlethal damage instead of lethal            MM  PRG:APG
# 653  Creatures who saved against a spell must save ...            MM  PRG:APG
# 654  Affected spell treats creatures with SR as hav...            MM   PRG:UM
# 655                       Cast spell as a swift action            MM  PRG:CRB
# 656      Increase spell range to higher range category            MM  PRG:APG
# 657  Spell with the cold descriptor also entangles ...            MM   PRG:UM
# 658          Exclude targets from an area effect spell            MM  PRG:APG
# 659                  Sicken creature with spell damage            MM  PRG:APG
# 660               Cast spell without verbal components            MM  PRG:CRB
# 661              Cast spell without somatic components            MM  PRG:CRB
# 662  Affected spell’s death effects, energy drain, ...            MM   PRG:UM
# 663  Change a mind-affecting spell so it can affect...            MM   PRG:UM
# 664                  Deafen creature with spell damage            MM  PRG:APG
# 665  Spell with the force descriptor knocks targets...            MM   PRG:UM
# 666                                  Double spell area            MM  PRG:CRB
# 667                                           Benefits  Feat Type(s)   Source
# 668  +2 bonus on level checks to overcome spell res...             T  PRG:APG
# 669                    Damage a target while grappling          C, T      OoG
# 670                                    +2 bonus to CMD          C, T  PRG:APG
# 671                 +2 bonus on combat maneuver checks          C, T  PRG:APG
# 672          Take ally’s result on Reflex saving throw             T  PRG:APG
# 673      Nearby performers can aid your perform checks             T   PRG:UM
# 674              Act in surprise round if ally can act          C, T  PRG:APG
# 675        Gain +4 bonus on attack rolls when flanking          C, T  PRG:APG
# 676                 +4 bonus on attacks of opportunity          C, T  PRG:APG
# 677  Deal +1d6 points of precision damage with mele...          C, T  PRG:APG
# 678                   Increase your shield bonus to AC          C, T  PRG:APG
# 679                   +4 bonus on concentration checks             T  PRG:APG
# 680                Switch places with an adjacent ally          C, T  PRG:APG
#
# [681 rows x 5 columns]

# %%
## What a beautiful, clean, and simple dataframe with literally everything we could want. Looks like it didn't keep the column names though, it put them in as part of the data. We'll do some cleaning.

df.columns = ['Feat','Prerequisite','Benefits','Feat Types(s)','Source']

# %%
## So that renamed the columns. But I know that there's a few instances of that in the code, because some tables are sectioned, like teamwork feats. Let's remove those now. Every header would contain a Benefits section-- really only the first column's name would change. Benefits will remove any of the 'headers' across the board.
df = df[~df['Benefits'].isin(['Benefits'])]

print(df)
# Out:
#                           Feat  \
# 1         Abundant Revelations
# 2                 Accursed Hex
# 3                    Acrobatic
# 4            Additional Traits
# 5               Adept Champion
# 6         Advanced Ranger Trap
# 7             Agile Maneuvers*
# 8              Under and Over*
# 9                    Alertness
# 10           Uncanny Alertness
# 11           Alignment Channel
# 12         Amateur Gunslinger*
# 13             Animal Affinity
# 14                  Antagonize
# 15                Arcane Blast
# 16               Arcane Shield
# 17              Arcane Strike*
# 18         Dispelling Critical
# 19               Arcane Talent
# 20    Armor Proficiency, Light
# 21      Arcane Armor Training*
# 22       Arcane Armor Mastery*
# 23   Armor Proficiency, Medium
# 24       Arcane Armor Mastery*
# 25    Armor Proficiency, Heavy
# 26         Aspect of the Beast
# 27                    Athletic
# 29               Blade Binder*
# 30                Blind-Fight*
# 31       Improved Blind-Fight*
# ..                         ...
# 650            Lingering Spell
# 651             Maximize Spell
# 652             Merciful Spell
# 653           Persistent Spell
# 654             Piercing Spell
# 655              Quicken Spell
# 656                Reach Spell
# 657                 Rime Spell
# 658            Selective Spell
# 659            Sickening Spell
# 660               Silent Spell
# 661                Still Spell
# 662           Thanatopic Spell
# 663            Threnodic Spell
# 664           Thundering Spell
# 665             Toppling Spell
# 666                Widen Spell
# 668         Allied Spellcaster
# 669           Brutal Grappler*
# 670       Coordinated Defense*
# 671     Coordinated Maneuvers*
# 672             Duck and Cover
# 673                   Ensemble
# 674                   Lookout*
# 675                  Outflank*
# 676       Paired Opportunists*
# 677            Precise Strike*
# 678               Shield Wall*
# 679            Shielded Caster
# 680               Swap Places*
#
#                                           Prerequisite  \
# 1                                Mystery class feature
# 2                                    Hex class feature
# 3                                                    —
# 4                                                    —
# 5       Smite evil class feature, base attack bonus +5
# 6                 Trap class feature, ranger level 5th
# 7                                                    —
# 8               Agile Maneuvers, Small size or smaller
# 9                                                    —
# 10                                           Alertness
# 11                        Channel energy class feature
# 12        No levels in a class with grit class feature
# 13                                                   —
# 14                                                   —
# 15               Arcane spellcaster, caster level 10th
# 16               Arcane spellcaster, caster level 10th
# 17                       Ability to cast arcane spells
# 18   Arcane strike, base attack bonus + 11, ability...
# 19                     Cha 10; elf, half-elf, or gnome
# 20                                                   —
# 21          Armor Proficiency, Light, caster level 3rd
# 22   Arcane Armor Training, Armor Proficiency, Medi...
# 23                            Armor Proficiency, Light
# 24   Arcane Armor Training, Armor Proficiency, Medi...
# 25                           Armor Proficiency, Medium
# 26                            Wild shape class feature
# 27                                                   —
# 29   Base attack bonus +4, proficiency with khopesh...
# 30                                                   —
# 31                    Perception 10 ranks, Blind-Fight
# ..                                                 ...
# 650                                                  —
# 651                                                  —
# 652                                                  —
# 653                                                  —
# 654                                                  —
# 655                                                  —
# 656                                                  —
# 657                                                  —
# 658                                Spellcraft 10 ranks
# 659                                                  —
# 660                                                  —
# 661                                                  —
# 662  Knowledge (religion) 6 ranks, Spell Focus (nec...
# 663  Knowledge (religion) 6 ranks, Spell Focus (enc...
# 664                                                  —
# 665                                                  —
# 666                                                  —
# 668                                   Caster level 1st
# 669                                    Half-orc or orc
# 670                                                  —
# 671                                                  —
# 672                                                  —
# 673                                    Perform 5 ranks
# 674                                                  —
# 675                               Base attack bonus +4
# 676                                                  —
# 677                       Dex 13, base attack bonus +1
# 678                                 Shield Proficiency
# 679                                                  —
# 680                                                  —
#
#                                               Benefits Feat Types(s)   Source
# 1          Use a single revelation more times each day             G   PRG:UM
# 2    Target a creature with a hex a second time tha...             G   PRG:UM
# 3                +2 bonus on Acrobatics and Fly checks             G  PRG:CRB
# 4                 Gain two additional character traits             G  PRG:APG
# 5    Trade smite evil damage for bonus on combat ma...             G   PRG:UC
# 6    Add +1 to the Disable Device and Perception ch...             G   PRG:UM
# 7         Use your Dex bonus when calculating your CMB          G, C  PRG:CRB
# 8    Failed grapples against you cause attacker to ...          G, C  PRG:APG
# 9       +2 bonus on Perception and Sense Motive checks             G  PRG:CRB
# 10   +1 on Perception and Sense Motive checks and a...             G   PRG:UM
# 11           Channel energy can heal or harm outsiders             G  PRG:CRB
# 12   Gain limited amount of grit and access to guns...          G, C   PRG:UC
# 13           +2 bonus on Handle Animal and Ride checks             G  PRG:CRB
# 14       Use Diplomacy or Intimidate to goad creatures             G   PRG:UM
# 15                Sacrifice a spell to make ray attack             G  PRG:APG
# 16    Sacrifice a spell to gain deflection bonus to AC             G  PRG:APG
# 17          +1 damage and weapons are considered magic          G, C  PRG:CRB
# 18       After critical hit, you may cast dispel magic       G, Crit   PRG:UC
# 19   Cast a 0-level spell 3 times per day as a spel...             G  PRG:APG
# 20   No penalties on attack rolls while wearing lig...             G  PRG:CRB
# 21      Reduce your arcane spell failure chance by 10%          G, C  PRG:CRB
# 22      Reduce your arcane spell failure chance by 20%          G, C  PRG:CRB
# 23   No penalties on attack rolls while wearing med...             G  PRG:CRB
# 24      Reduce your arcane spell failure chance by 20%          G, C  PRG:CRB
# 25   No penalties on attack rolls while wearing hea...             G  PRG:CRB
# 26                 Gain one of four bestial advantages             G  PRG:APG
# 27                   +2 bonus on Climb and Swim checks             G  PRG:CRB
# 29          +2 bonus to CMB checks with blade-binding.          G, C   PCh:CS
# 30                 Reroll miss chances for concealment          G, C  PRG:CRB
# 31   Ignore miss chance for less than total conceal...          G, C  PRG:APG
# ..                                                 ...           ...      ...
# 650  Instantaneous area effect spell lasts for 1 round            MM  PRG:APG
# 651                           Maximize spell variables            MM  PRG:CRB
# 652  Spell inflicts nonlethal damage instead of lethal            MM  PRG:APG
# 653  Creatures who saved against a spell must save ...            MM  PRG:APG
# 654  Affected spell treats creatures with SR as hav...            MM   PRG:UM
# 655                       Cast spell as a swift action            MM  PRG:CRB
# 656      Increase spell range to higher range category            MM  PRG:APG
# 657  Spell with the cold descriptor also entangles ...            MM   PRG:UM
# 658          Exclude targets from an area effect spell            MM  PRG:APG
# 659                  Sicken creature with spell damage            MM  PRG:APG
# 660               Cast spell without verbal components            MM  PRG:CRB
# 661              Cast spell without somatic components            MM  PRG:CRB
# 662  Affected spell’s death effects, energy drain, ...            MM   PRG:UM
# 663  Change a mind-affecting spell so it can affect...            MM   PRG:UM
# 664                  Deafen creature with spell damage            MM  PRG:APG
# 665  Spell with the force descriptor knocks targets...            MM   PRG:UM
# 666                                  Double spell area            MM  PRG:CRB
# 668  +2 bonus on level checks to overcome spell res...             T  PRG:APG
# 669                    Damage a target while grappling          C, T      OoG
# 670                                    +2 bonus to CMD          C, T  PRG:APG
# 671                 +2 bonus on combat maneuver checks          C, T  PRG:APG
# 672          Take ally’s result on Reflex saving throw             T  PRG:APG
# 673      Nearby performers can aid your perform checks             T   PRG:UM
# 674              Act in surprise round if ally can act          C, T  PRG:APG
# 675        Gain +4 bonus on attack rolls when flanking          C, T  PRG:APG
# 676                 +4 bonus on attacks of opportunity          C, T  PRG:APG
# 677  Deal +1d6 points of precision damage with mele...          C, T  PRG:APG
# 678                   Increase your shield bonus to AC          C, T  PRG:APG
# 679                   +4 bonus on concentration checks             T  PRG:APG
# 680                Switch places with an adjacent ally          C, T  PRG:APG
#
# [658 rows x 5 columns]

# %%
## So this is now all set up and I can search about, not in SQL yet, but lets check out what feats I'd need Shield Proficiency to take.

for row in df[df.Prerequisite.isin(["Shield Proficiency"])].itertuples():
    print(row[1:])
# Out:
# ('Improved Shield Bash*', 'Shield Proficiency', 'Keep your shield bonus when shield bashing', 'G, C', 'PRG:CRB')
# ('Saving Shield*', 'Shield Proficiency', 'Grant shield bonus to an adjacent ally', 'G, C', 'PRG:APG')
# ('Shield Wall*', 'Shield Proficiency', 'Increase your shield bonus to AC', 'C, T', 'PRG:CRB')
# ('Tower Shield Proficiency*', 'Shield Proficiency', 'No penalties on attack rolls when using a tower shield', 'G, C', 'PRG:CRB')
# ('Shield Wall*', 'Shield Proficiency', 'Increase your shield bonus to AC', 'C, T', 'PRG:APG')

# %%
## Nice, that makes sense. Note without the row[1:] we'd see "pandas" before everything. Let's look for particular sources-- let's look for feats from the Pathfinder Roleplaying Game: Advanced Player's Guide and Orcs of Golarions books.

for row in df[df.Source.isin(["PRG:APG","OoG"])].itertuples():
    print(row[1:])
# Out:
# ('Additional Traits', '—', 'Gain two additional character traits', 'G', 'PRG:APG')
# ('Under and Over*', 'Agile Maneuvers, Small size or smaller', 'Failed grapples against you cause attacker to fall prone', 'G, C', 'PRG:APG')
# ('Arcane Blast', 'Arcane spellcaster, caster level 10th', 'Sacrifice a spell to make ray attack', 'G', 'PRG:APG')
# ('Arcane Shield', 'Arcane spellcaster, caster level 10th', 'Sacrifice a spell to gain deflection bonus to AC', 'G', 'PRG:APG')
# ('Arcane Talent', 'Cha 10; elf, half-elf, or gnome', 'Cast a 0-level spell 3 times per day as a spell-like ability', 'G', 'PRG:APG')
# ('Aspect of the Beast', 'Wild shape class feature', 'Gain one of four bestial advantages', 'G', 'PRG:APG')
# ('Improved Blind-Fight*', 'Perception 10 ranks, Blind-Fight', 'Ignore miss chance for less than total concealment', 'G, C', 'PRG:APG')
# ('Greater Blind-Fight*', 'Perception 15 ranks, Improved Blind-Fight', 'Total concealment is considered normal concealment', 'G, C', 'PRG:APG')
# ('Breadth of Experience', 'Dwarf, elf, or gnome; 100+ years old', '+2 bonus on all Knowledge and Profession checks', 'G', 'PRG:APG')
# ('Childlike', 'Cha 13, halfling', '+2 on Disguise checks to look like human child, take 10 on Bluff checks', 'G', 'PRG:APG')
# ('Gang Up*', 'Combat Expertise', 'Flank an opponent if at least two allies are adjacent to it', 'G, C', 'PRG:APG')
# ('Team Up*', 'Gang-Up, base attack bonus +6', 'Aid another as a move action with two adjacent allies', 'G, C', 'PRG:APG')
# ('Improved Dirty Trick*', 'Combat Expertise', '+2 bonus on dirty trick attempts, no attack of opportunity', 'G, C', 'PRG:APG')
# ('Greater Dirty Trick*', 'Improved Dirty Trick, base attack bonus +6', 'Dirty trick penalty lasts 1d4 rounds', 'G, C', 'PRG:APG')
# ('Disarming Strike*', 'Improved Disarm, base attack bonus +9', 'Attempt a disarm on a successful critical hit', 'G, C', 'PRG:APG')
# ('Improved Reposition*', 'Combat Expertise', '+2 bonus on reposition attempts, no attack of opportunity', 'G, C', 'PRG:APG')
# ('Greater Reposition*', 'Improved Reposition, base attack bonus +6', 'Enemies you reposition provoke attacks of opportunity', 'G, C', 'PRG:APG')
# ('Repositioning Strike*', 'Improved Reposition, base attack bonus +9', 'Attempt a reposition attack on a successful critical hit', 'G, C', 'PRG:APG')
# ('Improved Steal*', 'Combat Expertise', '+2 bonus on steal attempts, no attack of opportunity', 'G, C', 'PRG:APG')
# ('Greater Steal*', 'Improved Steal, base attack bonus +6', 'Enemies don’t notice theft until after combat', 'G, C', 'PRG:APG')
# ('Ki Throw*', 'Improved Trip, Improved Unarmed Strike', 'Throw opponent into adjacent square with a trip attack', 'G, C', 'PRG:APG')
# ('Improved Ki Throw*', 'Improved Bull Rush, Ki Throw', 'Throw opponent into occupied square as a bull rush', 'G, C', 'PRG:APG')
# ('Tripping Strike*', 'Improved Trip, base attack bonus +9', 'Attempt a trip attack on a successful critical hit', 'G, C', 'PRG:APG')
# ('Second Chance*', 'Combat Expertise, base attack bonus +6', 'Exchange later attacks to reroll missed first attack', 'G, C', 'PRG:APG')
# ('Improved Second Chance*', 'Second Chance, base attack bonus +11', 'Take a –5 penalty on later attacks to reroll missed attack', 'G, C', 'PRG:APG')
# ('Swift Aid*', 'Combat Expertise, base attack bonus +6', 'Attempt to aid another as a swift action', 'G, C', 'PRG:APG')
# ('Bodyguard*', 'Combat Reflexes', 'Use attack of opportunity to add a bonus to adjacent ally’s AC', 'G, C', 'PRG:APG')
# ('In Harm’s Way*', 'Bodyguard', 'Take the damage of a successful attack upon an adjacent ally', 'G, C', 'PRG:APG')
# ('Combat Patrol*', 'Combat Reflexes, Mobility, base attack bonus +5', 'Increase threatened area for attack of opportunity', 'G, C', 'PRG:APG')
# ('Teleport Tactician*', 'Combat Reflexes, Disruptive, Spellbreaker', 'Teleporting creatures provoke attacks of opportunity', 'G, C', 'PRG:APG')
# ('Cooperative Crafting', '1 rank in any Craft skill, any item creation feat', '+2 bonus on Craft or Spellcraft checks while working together', 'G', 'PRG:APG')
# ('Cosmopolitan', '—', 'Read and speak two additional languages', 'G', 'PRG:APG')
# ('Crippling Critical*', 'Critical Focus, base attack bonus +13', 'Whenever you score a critical hit, the target’s speed is halved', 'G, C', 'PRG:APG')
# ('Dastardly Finish*', 'Sneak attack +5d6', 'Deliver coup de grace to cowering or stunned target', 'G, C', 'PRG:APG')
# ('Deep Drinker', 'Con 13, monk level 11, drunken ki class feature', 'Gain 2 temporary ki from drunken ki', 'G', 'PRG:APG')
# ('Deepsight', 'Darkvision 60 feet', 'Your darkvision has a range of 120 feet', 'G', 'PRG:APG')
# ('Destroyer’s Blessing*', 'Half-orc or orc, rage class feature, worshiper of the Destroyer', 'Regain rage by sundering.', 'G, C', 'OoG')
# ('Ray Shield*', 'Dex 15, Missile Shield, Spellbreaker', 'Deflect one ranged touch attack per round with shield', 'G, C', 'PRG:APG')
# ('Teleport Tactician*', 'Combat Reflexes, Disruptive, Spellbreaker', 'Teleporting creatures provoke attacks of opportunity', 'G, C', 'PRG:APG')
# ('Combat Patrol*', 'Combat Reflexes, Mobility, base attack bonus +5', 'Increase threatened area for attack of opportunity', 'G, C', 'PRG:APG')
# ('Sidestep*', 'Dex 13, Dodge, Mobility', 'Make 5-foot step immediately after an opponent misses', 'G, C', 'PRG:APG')
# ('Improved Sidestep*', 'Dex 15, Sidestep', 'Sidestep without using your 5-foot step on your next turn', 'G, C', 'PRG:APG')
# ('Underfoot*', 'Dodge, Mobility, Small size or smaller', '+4 on Acrobatics checks to move past larger opponents', 'G, C', 'PRG:APG')
# ('Eagle Eyes', 'Wis 13, keen senses racial trait', 'Ignore up to –5 due to distance on visual Perception checks', 'G', 'PRG:APG')
# ('Eclectic', 'Human', 'Gain an additional favored class', 'G', 'PRG:APG')
# ('Eldritch Claws', 'Str 15, natural weapons, base attack bonus +6', 'Natural weapons treated as magic and silver', 'G', 'PRG:APG')
# ('Elemental Focus', '—', '+1 bonus on save DCs for one energy type', 'G', 'PRG:APG')
# ('Greater Elemental Focus', 'Elemental Focus', '+1 bonus on save DCs for one energy type', 'G', 'PRG:APG')
# ('Elven Accuracy*', 'Elf', 'Reroll miss chance due to concealment when using a bow', 'G, C', 'PRG:APG')
# ('Fast Healer', 'Con 13, Diehard, Endurance', 'Regain additional hit points when healing', 'G', 'PRG:APG')
# ('Heroic Defiance', 'Diehard, base Fortitude save +8', 'Once per day, delay onset of harmful condition for 1 round', 'G', 'PRG:APG')
# ('Heroic Recovery', 'Diehard, base Fortitude save +4', 'Once per day, gain new saving throw against harmful condition requiring Fort save', 'G', 'PRG:APG')
# ('Enforcer*', 'Intimidate 1 rank', 'Demoralize opponent as free action when you inflict nonlethal damage', 'G, C', 'PRG:APG')
# ('Expanded Arcana', 'Caster level 1st, see feat', 'Add one or two spells to list of spells known', 'G', 'PRG:APG')
# ('Extra Bombs', 'Bomb class feature', 'Throw two additional bombs per day', 'G', 'PRG:APG')
# ('Extra Discovery', 'Discovery class feature', 'Gain one additional discovery', 'G', 'PRG:APG')
# ('Extra Hex', 'Hex class feature', 'Gain one additional hex', 'G', 'PRG:APG')
# ('Extra Rage Power', 'Rage power class feature', 'Gain one additional rage power', 'G', 'PRG:APG')
# ('Extra Revelation', 'Revelation class feature', 'Gain one additional revelation', 'G', 'PRG:APG')
# ('Extra Rogue Talent', 'Rogue talent class feature', 'Gain one additional rogue talent', 'G', 'PRG:APG')
# ('Fast Drinker', 'Con 18, drunken ki class feature', 'Drink as a swift action', 'G', 'PRG:APG')
# ('Favored Defense', 'Favored enemy class feature', 'Bonus to CMD and AC when attacked by favored enemy', 'G', 'PRG:APG')
# ('Ferocious Tenacity*', 'Half-orc or orc, ferocity racial trait, rage class feature', 'Negate some damage when it would otherwise kill you by expending rage points.', 'G, C', 'OoG')
# ('Fight On', 'Con 13; dwarf, half-orc, or orc', 'Gain temporary hit points when reduced to 0', 'G', 'PRG:APG')
# ('Gnome Trickster', 'Cha 13, gnome, gnome magic racial trait', 'Use mage hand and prestidigitation once per day', 'G', 'PRG:APG')
# ('Go Unnoticed', 'Dex 13, Small size or smaller', 'Make Stealth check against flat-footed opponents during first round of combat', 'G', 'PRG:APG')
# ('Gore Fiend*', 'Half-orc or orc, rage class feature', 'Regain rounds of rage by dealing or suffering critical hits.', 'G, C', 'OoG')
# ('Groundling', 'Cha 13, gnome, gnome magic racial trait', 'Speak with burrowing animals as spell-like ability', 'G', 'PRG:APG')
# ('Hero’s Fortune', '—', 'You gain a hero point. The maximum number of hero points you can have at any one time is increased to 5.', 'G', 'PRG:APG')
# ('Parry Spell', 'Spellcraft 15 ranks, Improved Counterspell', 'Reflect a counterspelled spell back on its caster', 'G', 'PRG:APG')
# ('Improved Share Spells', 'Spellcraft 10 ranks, see feat', 'Spells affect both you and your bonded creature', 'G', 'PRG:APG')
# ('Improved Stonecunning', 'Wis 13, dwarf, stonecunning racial trait', '+4 bonus on Perception checks to notice unusual stonework', 'G', 'PRG:APG')
# ('Stone Sense', 'Perception 10 ranks, Improved Stonecunning', 'Gain tremorsense 10 ft.', 'G', 'PRG:APG')
# ('Elemental Fist*', 'Con 13, Wis 13, Improved Unarmed Strike, base attack bonus +8', 'Deal 1d6 energy damage with an unarmed strike', 'G, C', 'PRG:APG')
# ('Ki Throw*', 'Improved Trip, Improved Unarmed Strike', 'Throw opponent into adjacent square with a trip attack', 'G, C', 'PRG:APG')
# ('Improved Ki Throw*', 'Improved Bull Rush, Ki Throw', 'Throw opponent into occupied square as a bull rush', 'G, C', 'PRG:APG')
# ('Perfect Strike*', 'Dex 13, Wis 13, Improved Unarmed Strike, base attack bonus +8', 'Roll twice for unarmed strikes and take the better roll', 'G, C', 'PRG:APG')
# ('Punishing Kick*', 'Con 13, Wis 13, Improved Unarmed Strike, base attack bonus +8', 'Knock down or push back foes with unarmed strikes', 'G, C', 'PRG:APG')
# ('Cockatrice Strike*', 'Medusa’s Wrath, base attack bonus +14', 'Turn a target to stone with a critical hit', 'G, C', 'PRG:APG')
# ('Touch of Serenity*', 'Wis 18, Improved Unarmed Strike, base attack bonus +8', 'Foes hit by unarmed strikes cannot attack or cast spells', 'G, C', 'PRG:APG')
# ('Ironguts', 'Con 13; dwarf, half-orc, or orc', '+2 on saves against nausea, sickening, and ingested poisons', 'G', 'PRG:APG')
# ('Ironhide', 'Con 13; dwarf, half-orc, or orc', '+1 natural armor bonus to AC', 'G', 'PRG:APG')
# ('Keen Scent', 'Wis 13, half-orc or orc', 'Gain the scent special ability', 'G', 'PRG:APG')
# ('Smell Fear', 'Keen Scent, half-orc or orc', '+4 on Perception checks to detect frightened creatures', 'G', 'PRG:APG')
# ('Leaf Singer', 'Cha 13, bardic performance, elf or half-elf', 'Gain benefits to bardic performance in forests and against fey', 'G', 'PRG:APG')
# ('Lingering Performance', 'Bardic performance class ability', 'Bardic performance continues for 2 rounds after you stop performing', 'G', 'PRG:APG')
# ('Low Profile*', 'Dex 13, Small size or smaller', '+1 dodge bonus to AC against ranged attacks', 'G, C', 'PRG:APG')
# ('Lucky Halfling', 'Halfling', 'You may roll saving throw for an ally once per day', 'G', 'PRG:APG')
# ('Master Alchemist', 'Craft (alchemy) 5 ranks', '+2 on Craft (alchemy) checks, and you can create alchemical items and poisons faster', 'G', 'PRG:APG')
# ('Minor Spell Expertise', 'Cast 4th-level spells', 'Cast 1st-level spell as spell-like ability 2/day', 'G', 'PRG:APG')
# ('Major Spell Expertise', 'Minor Spell Expertise, cast 9th-level spells', 'Cast 5th-level or lower spell as spell-like ability 2/day', 'G', 'PRG:APG')
# ('Mounted Shield*', 'Mounted Combat, Shield Focus', 'Apply shield bonus to mount’s AC', 'G, C', 'PRG:APG')
# ('Trick Riding*', 'Ride rank 9, Mounted Combat', 'Automatically pass simple Ride skill checks', 'G, C', 'PRG:APG')
# ('Mounted Skirmisher*', 'Ride rank 14, Trick Riding', 'Make a full attack if mount moves its speed or less', 'G, C', 'PRG:APG')
# ('Light Step', 'Acrobatic Steps, Nimble Moves, elf', 'Move normal speed in difficult terrain', 'G', 'PRG:APG')
# ('Pass for Human', 'Half-elf, half-orc, or halfling', '+10 on Disguise checks to look like a human', 'G', 'PRG:APG')
# ('Disrupting Shot*', 'Dex 13, Point-Blank Shot, 6th-level fighter', 'Ranged attacks increase enemy’s DC to cast spells', 'G, C', 'PRG:APG')
# ('Focused Shot*', 'Int 13, Precise Shot', 'Add Int modifier on damage rolls with bows or crossbows', 'G, C', 'PRG:APG')
# ('Crossbow Mastery*', 'Dex 15, Rapid Reload, Rapid Shot', 'Reload crossbow as free action and make full attacks', 'G, C', 'PRG:APG')
# ('Stabbing Shot*', 'Rapid Shot, elf', 'Use arrow as a melee attack to push enemies back', 'G, C', 'PRG:APG')
# ('Bloody Assault*', 'Power Attack, base attack bonus +6', 'Trade melee attack bonus for bleed damage', 'G, C', 'PRG:APG')
# ('Dazing Assault*', 'Power Attack, base attack bonus +11', 'Trade melee attack bonus to daze opponents', 'G, C', 'PRG:APG')
# ('Furious Focus*', 'Str 13, Power Attack, base attack bonus +1', 'Do not take the Power Attack penalty on the first attack each round', 'G, C', 'PRG:APG')
# ('Dreadful Carnage*', 'Str 15, Furious Focus, base attack bonus +11', 'Make a free Intimidate check when you knock down a foe', 'G, C', 'PRG:APG')
# ('Bull Rush Strike*', 'Improved Bull Rush, base attack bonus +9', 'Attempt a bull rush on a successful critical hit', 'G, C', 'PRG:APG')
# ('Improved Ki Throw*', 'Improved Bull Rush, Ki Throw', 'Throw opponent into occupied square as a bull rush', 'G, C', 'PRG:APG')
# ('Improved Drag*', 'Power Attack', '+2 bonus on drag attempts, no attack of opportunity', 'G, C', 'PRG:APG')
# ('Greater Drag*', 'Improved Drag, base attack bonus +6', 'Enemies you drag provoke attacks of opportunity', 'G, C', 'PRG:APG')
# ('Charge Through*', 'Improved Overrun, base attack bonus +1', 'Make overrun as free action while charging', 'G, C', 'PRG:APG')
# ('Sundering Strike*', 'Improved Sunder, base attack bonus +9', 'Attempt a sunder attack on a successful critical hit', 'G, C', 'PRG:APG')
# ('Pushing Assault*', 'Str 15, Power Attack, base attack bonus +1', 'Push a foe back with a two-handed weapon', 'G, C', 'PRG:APG')
# ('Shield of Swings*', 'Str 13, Power Attack, base attack bonus +1', 'Reduce damage with a two handed weapon to gain a +4 shield bonus', 'G, C', 'PRG:APG')
# ('Smash*', 'Power Attack, half-orc', 'Ignore 5 points of hardness when breaking an object', 'G, C', 'PRG:APG')
# ('Stunning Assault*', 'Power Attack, base attack bonus +16', 'Trade melee attack bonus to stun opponents', 'G, C', 'PRG:APG')
# ('Practiced Tactician', 'Tactician class feature', 'Use tactician ability one additional time per day', 'G', 'PRG:APG')
# ('Preferred Spell', 'Spellcraft 5 ranks, Heighten Spell', 'Spontaneously cast a specific spell', 'G', 'PRG:APG')
# ('Racial Heritage', 'Human', 'Affected as though both human and another race', 'G', 'PRG:APG')
# ('Raging Vitality', 'Con 15, rage class feature', '+2 bonus to Con when raging, and continue raging if unconscious', 'G', 'PRG:APG')
# ('Crossbow Mastery*', 'Dex 15, Rapid Reload, Rapid Shot', 'Reload crossbow as free action and make full attacks', 'G, C', 'PRG:APG')
# ('Razortusk', 'Half-orc', 'Gain bite attack', 'G', 'PRG:APG')
# ('Rending Claws*', 'Str 13, two claw attacks, base attack bonus +6', 'Deal 1d6 extra damage if both claws hit', 'G, C', 'PRG:APG')
# ('Shadow Strike*', 'Base attack bonus +1', 'Deal precision damage against targets with concealment', 'G, C', 'PRG:APG')
# ('Shared Insight', 'Wis 13, half-elf', 'Grant friendly creatures a +2 bonus on Perception checks', 'G', 'PRG:APG')
# ('Sharp Senses', 'Keen senses racial trait', '+4 racial bonus on Perception checks', 'G', 'PRG:APG')
# ('Saving Shield*', 'Shield Proficiency', 'Grant shield bonus to an adjacent ally', 'G, C', 'PRG:APG')
# ('Covering Defense*', 'Shield Focus, base attack bonus +6', 'Provide cover to an ally with total defense', 'G, C', 'PRG:APG')
# ('Greater Shield Specialization*', 'Greater Shield Focus, Shield Specialization, 12th-level fighter', '+2 bonus to AC against criticals, and negate critical hit once per day', 'G, C', 'PRG:APG')
# ('Missile Shield*', 'Dex 13, Shield Focus', 'Deflect one ranged attack per round with shield', 'G, C', 'PRG:APG')
# ('Ray Shield*', 'Dex 15, Missile Shield, Spellbreaker', 'Deflect one ranged touch attack per round with shield', 'G, C', 'PRG:APG')
# ('Mounted Shield*', 'Mounted Combat, Shield Focus', 'Apply shield bonus to mount’s AC', 'G, C', 'PRG:APG')
# ('Shield Specialization*', 'Shield Focus, 4th-level fighter', '+2 bonus to AC against criticals with one type of shield', 'G, C', 'PRG:APG')
# ('Greater Shield Specialization*', 'Greater Shield Focus, Shield Specialization, 12th-level fighter', '+2 bonus to AC against criticals, and negate critical hit once per day', 'G, C', 'PRG:APG')
# ('Bashing Finish*', 'Shield Master, Two-Weapon Fighting, base attack bonus +11', 'Make a free shield bash after a critical hit', 'G, C', 'PRG:APG')
# ('Sociable', 'Cha 13, half-elf', 'Grant friendly creatures a +2 bonus on Diplomacy checks', 'G', 'PRG:APG')
# ('Diviner’s Delving', 'Spell Focus (divination)', '+2 bonus on caster level checks with divinations', 'G', 'PRG:APG')
# ('Tenacious Transmutation', 'Spell Focus (transmutation)', '+2 to DC to dispel your transmutations', 'G', 'PRG:APG')
# ('Spell Perfection', 'Spellcraft 15 ranks, 3 metamagic feats', 'Apply any metamagic feat to one spell without penalty, up to 9th level', 'G', 'PRG:APG')
# ('Spider Step', 'Acrobatics 6 ranks, Climb 6 ranks, 6th-level monk', 'Walk on walls or ceilings for half your slow fall distance', 'G', 'PRG:APG')
# ('Cloud Step', 'Spider Step, 12th-level monk', 'Air walk for half your slow fall distance', 'G', 'PRG:APG')
# ('Steel Soul', 'Dwarf, hardy racial trait', '+4 racial bonus on saves against spells and spell-like abilities', 'G', 'PRG:APG')
# ('Following Step*', 'Dex 13, Step Up', 'Move up to 10 feet as an immediate action', 'G, C', 'PRG:APG')
# ('Step Up and Strike*', 'Following Step, base attack bonus +6', 'Follow adjacent creature and attack as an immediate action', 'G, C', 'PRG:APG')
# ('Stone-Faced', 'Dwarf', '+4 bonus on Bluff checks to lie or conceal motives', 'G', 'PRG:APG')
# ('Stone Singer', 'Cha 13, bardic performance, dwarf', 'Gain benefits to bardic performance underground and against earth creatures', 'G', 'PRG:APG')
# ('Summoner’s Call', 'Eidolon class feature', 'Your eidolon gets a bonus when summoned', 'G', 'PRG:APG')
# ('Taunt', 'Cha 13, Small size or smaller', 'Demoralize opponents with Bluff instead of Intimidate', 'G', 'PRG:APG')
# ('Bashing Finish*', 'Shield Master, Two-Weapon Fighting, base attack bonus +11', 'Make a free shield bash after a critical hit', 'G, C', 'PRG:APG')
# ('Vermin Heart', 'Wild empathy class feature', 'Target vermin with spells as if they were animals', 'G', 'PRG:APG')
# ('War Singer', 'Cha 13, bardic performance, half-orc or orc', 'Gain benefits to bardic performance on battlefields and against orcs', 'G', 'PRG:APG')
# ('Point-Blank Master*', 'Weapon Specialization with a ranged weapon', 'Do not provoke attacks of opportunity while firing one ranged weapon', 'G, C', 'PRG:APG')
# ('Well-Prepared', 'Halfling', 'Retrieve a specific mundane item from your person', 'G', 'PRG:APG')
# ('Bouncing Spell', '—', 'Redirect a spell that had no effect on initial target', 'MM', 'PRG:APG')
# ('Dazing Spell', '—', 'Daze creature with spell damage', 'MM', 'PRG:APG')
# ('Disruptive Spell', '—', 'Target of spell must make concentration check to cast a spell in the next round', 'MM', 'PRG:APG')
# ('Ectoplasmic Spell', '—', 'Spell fully affects incorporeal and ethereal creatures', 'MM', 'PRG:APG')
# ('Elemental Spell', '—', 'Inflict energy damage instead of regular spell damage', 'MM', 'PRG:APG')
# ('Focused Spell', '—', 'Increase save DC of spell for one target in a group', 'MM', 'PRG:APG')
# ('Preferred Spell', 'Spellcraft 5 ranks, Heighten Spell', 'Spontaneously cast a specific spell', 'G', 'PRG:APG')
# ('Intensified Spell', '—', 'Increase maximum damage dice by 5 levels', 'MM', 'PRG:APG')
# ('Lingering Spell', '—', 'Instantaneous area effect spell lasts for 1 round', 'MM', 'PRG:APG')
# ('Merciful Spell', '—', 'Spell inflicts nonlethal damage instead of lethal', 'MM', 'PRG:APG')
# ('Persistent Spell', '—', 'Creatures who saved against a spell must save again', 'MM', 'PRG:APG')
# ('Reach Spell', '—', 'Increase spell range to higher range category', 'MM', 'PRG:APG')
# ('Selective Spell', 'Spellcraft 10 ranks', 'Exclude targets from an area effect spell', 'MM', 'PRG:APG')
# ('Sickening Spell', '—', 'Sicken creature with spell damage', 'MM', 'PRG:APG')
# ('Thundering Spell', '—', 'Deafen creature with spell damage', 'MM', 'PRG:APG')
# ('Allied Spellcaster', 'Caster level 1st', '+2 bonus on level checks to overcome spell resistance', 'T', 'PRG:APG')
# ('Brutal Grappler*', 'Half-orc or orc', 'Damage a target while grappling', 'C, T', 'OoG')
# ('Coordinated Defense*', '—', '+2 bonus to CMD', 'C, T', 'PRG:APG')
# ('Coordinated Maneuvers*', '—', '+2 bonus on combat maneuver checks', 'C, T', 'PRG:APG')
# ('Duck and Cover', '—', 'Take ally’s result on Reflex saving throw', 'T', 'PRG:APG')
# ('Lookout*', '—', 'Act in surprise round if ally can act', 'C, T', 'PRG:APG')
# ('Outflank*', 'Base attack bonus +4', 'Gain +4 bonus on attack rolls when flanking', 'C, T', 'PRG:APG')
# ('Paired Opportunists*', '—', '+4 bonus on attacks of opportunity', 'C, T', 'PRG:APG')
# ('Precise Strike*', 'Dex 13, base attack bonus +1', 'Deal +1d6 points of precision damage with melee attacks', 'C, T', 'PRG:APG')
# ('Shield Wall*', 'Shield Proficiency', 'Increase your shield bonus to AC', 'C, T', 'PRG:APG')
# ('Shielded Caster', '—', '+4 bonus on concentration checks', 'T', 'PRG:APG')
# ('Swap Places*', '—', 'Switch places with an adjacent ally', 'C, T', 'PRG:APG')

# %%
## Time to move this all towards sqlite.

db = sq.connect(":memory:")
cursor = db.cursor()
cursor.execute(""" 
   CREATE TABLE FEATS(FEATS, PREREQUISITE, BENEFIT, FEAT_TYPES, SOURCE)
""")
for row in df[df.Source.isin(["PRG:APG","OoG"])].itertuples():
    insert_sql_syntax = """
        INSERT INTO FEATS (FEATS, PREREQUISITE, BENEFIT, FEAT_TYPES, SOURCE)
        VALUES (?,?,?,?,?)
    """
    cursor.execute(insert_sql_syntax, row[1:])

db.commit()

# %%
## This is a query into the database that will show us some of the feats for the Orcs of Gollarion.

for row in cursor.execute("""
    SELECT FEATS, BENEFIT
    FROM FEATS
    WHERE SOURCE = "OoG"  
    """):
    print(row)
# Out:
# ('Destroyer’s Blessing*', 'Regain rage by sundering.')
# ('Ferocious Tenacity*', 'Negate some damage when it would otherwise kill you by expending rage points.')
# ('Gore Fiend*', 'Regain rounds of rage by dealing or suffering critical hits.')
# ('Brutal Grappler*', 'Damage a target while grappling')
